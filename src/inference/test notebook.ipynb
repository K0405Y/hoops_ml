# %%
import pandas as pd
import numpy as np
from databricks.sdk import WorkspaceClient
import io
import pickle as pkl

# Define the PlayerPredictionModel class (only the relevant parts for testing)
class PlayerPredictionModel:
    def __init__(self):
        self.player_data = None
        self.cols = None

    def load_data(self):
        workspace = WorkspaceClient()
        
        # Load columns from DBFS
        try:
            pkl_content = workspace.dbfs.download("dbfs:/FileStore/features.pkl")
            pkl_str = pkl_content.read()
            self.cols = pkl.loads(pkl_str)
            print(f"Columns loaded successfully: {self.cols}")
        except Exception as e:
            print(f"Failed to load column information: {str(e)}")
            raise RuntimeError(f"Failed to load column information: {str(e)}")
        
        # Load player data from DBFS
        try:
            file_content = workspace.dbfs.download("dbfs:/FileStore/inference_data.csv")
            file_str = file_content.read()
            file_content_stream = io.BytesIO(file_str)
            self.player_data = pd.read_csv(file_content_stream, encoding="latin1")
            
            # Preprocess the entire dataset
            self.player_data = self.player_data.sort_values(['Player', 'Year', 'G'], ascending=[True, False, False])
            self.player_data = self.player_data.groupby(['Player', 'Year']).first().reset_index()
            
            print(f"Player data loaded and preprocessed. Shape: {self.player_data.shape}")
        except Exception as e:
            print(f"Failed to load or preprocess player data: {str(e)}")
            raise RuntimeError(f"Failed to load or preprocess player data: {str(e)}")

    def calculate_player_averages(self, player_names):
        """
        This function calculates the averages of NBA player statistics for one or more players,
        including those with only one year of data.
        """
        # Ensure player_names is a list
        player_names = [player_names] if isinstance(player_names, str) else player_names

        # Filter the preprocessed data for the requested players
        player_data = self.player_data[self.player_data['Player'].isin(player_names)]

        # Ensure all columns in self.cols are present in player_data
        missing_cols = set(self.cols) - set(player_data.columns)
        if missing_cols:
            print(f"Columns {missing_cols} not found in player data. They will be excluded.")
            cols_to_use = [col for col in self.cols if col in player_data.columns]
        else:
            cols_to_use = self.cols

        def calc_player_stats(group):
            # Sort by Year descending
            sorted_group = group.sort_values('Year', ascending=False)
            # Take up to 3 most recent years, or all available if less than 3
            recent_years = sorted_group.iloc[:3]
            # Calculate mean of available data
            return recent_years[cols_to_use].mean()

        # Apply the calculation to each player
        player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()

        # Round numeric columns to 2 decimal places
        player_averages[cols_to_use] = player_averages[cols_to_use].round(2)

        # Check for truly missing players (not in the dataset at all)
        missing_players = set(player_names) - set(player_averages['Player'])
        if missing_players:
            print(f"No data found for players: {missing_players}")
            missing_df = pd.DataFrame({'Player': list(missing_players)})
            player_averages = pd.concat([player_averages, missing_df], ignore_index=True)

        print(f"Calculated averages for {len(player_averages)} players")
        return player_averages

# Create an instance of the model and load data
model = PlayerPredictionModel()
model.load_data()

# Test cases
test_cases = [
    ["LeBron James"],  # Player with multiple years of data
    ["Chet Holmgren"],  # Player with one year of data
    ["LeBron James", "Chet Holmgren"],  # Mix of players with different amounts of data
    ["LeBron James", "Chet Holmgren", "NonexistentPlayer"]  # Including a player not in the dataset
]

# Run tests
for i, players in enumerate(test_cases, 1):
    print(f"\nTest Case {i}: {players}")
    result = model.calculate_player_averages(players)
    print(result)
    print("\nColumns in result:")
    print(result.columns.tolist())
    print("\nData types of columns:")
    print(result.dtypes)

# Additional test: check for any NaN values in the result
for i, players in enumerate(test_cases, 1):
    print(f"\nChecking for NaN values in Test Case {i}: {players}")
    result = model.calculate_player_averages(players)
    nan_columns = result.columns[result.isna().any()].tolist()
    if nan_columns:
        print(f"Columns with NaN values: {nan_columns}")
    else:
        print("No NaN values found in the result.")
# Out:
# Columns loaded successfully: ['GS', 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'DRB', 'TRB', 'AST', 'STL', 'TOV']
# Player data loaded and preprocessed. Shape: (10287, 49)
#
# Test Case 1: ['LeBron James']
# Calculated averages for 1 players
#          Player     GS    MP    FG    FGA   3P   3PA    2P    2PA    FT   FTA  \
# 0  LeBron James  60.33  36.0  10.7  20.63  2.4  6.67  8.33  13.97  4.47  5.87
#
#     DRB   TRB  AST   STL  TOV
# 0  6.87  7.93  7.1  1.17  3.4
#
# Columns in result:
# ['Player', 'GS', 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'DRB', 'TRB', 'AST', 'STL', 'TOV']
#
# Data types of columns:
# Player     object
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# 3P        float64
# 3PA       float64
# 2P        float64
# 2PA       float64
# FT        float64
# FTA       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# TOV       float64
# dtype: object
#
# Test Case 2: ['Chet Holmgren']
# Calculated averages for 1 players
#           Player    GS    MP   FG   FGA   3P  3PA   2P  2PA   FT  FTA  DRB  \
# 0  Chet Holmgren  82.0  29.4  6.2  11.6  1.6  4.3  4.6  7.4  2.7  3.4  6.3
#
#    TRB  AST  STL  TOV
# 0  7.9  2.4  0.6  1.6
#
# Columns in result:
# ['Player', 'GS', 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'DRB', 'TRB', 'AST', 'STL', 'TOV']
#
# Data types of columns:
# Player     object
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# 3P        float64
# 3PA       float64
# 2P        float64
# 2PA       float64
# FT        float64
# FTA       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# TOV       float64
# dtype: object
#
# Test Case 3: ['LeBron James', 'Chet Holmgren']
# Calculated averages for 2 players
#           Player     GS    MP    FG    FGA   3P   3PA    2P    2PA    FT  \
# 0  Chet Holmgren  82.00  29.4   6.2  11.60  1.6  4.30  4.60   7.40  2.70
# 1   LeBron James  60.33  36.0  10.7  20.63  2.4  6.67  8.33  13.97  4.47
#
#     FTA   DRB   TRB  AST   STL  TOV
# 0  3.40  6.30  7.90  2.4  0.60  1.6
# 1  5.87  6.87  7.93  7.1  1.17  3.4
#
# Columns in result:
# ['Player', 'GS', 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'DRB', 'TRB', 'AST', 'STL', 'TOV']
#
# Data types of columns:
# Player     object
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# 3P        float64
# 3PA       float64
# 2P        float64
# 2PA       float64
# FT        float64
# FTA       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# TOV       float64
# dtype: object
#
# Test Case 4: ['LeBron James', 'Chet Holmgren', 'NonexistentPlayer']
# No data found for players: {'NonexistentPlayer'}
# Calculated averages for 3 players
#               Player     GS    MP    FG    FGA   3P   3PA    2P    2PA    FT  \
# 0      Chet Holmgren  82.00  29.4   6.2  11.60  1.6  4.30  4.60   7.40  2.70
# 1       LeBron James  60.33  36.0  10.7  20.63  2.4  6.67  8.33  13.97  4.47
# 2  NonexistentPlayer    NaN   NaN   NaN    NaN  NaN   NaN   NaN    NaN   NaN
#
#     FTA   DRB   TRB  AST   STL  TOV
# 0  3.40  6.30  7.90  2.4  0.60  1.6
# 1  5.87  6.87  7.93  7.1  1.17  3.4
# 2   NaN   NaN   NaN  NaN   NaN  NaN
#
# Columns in result:
# ['Player', 'GS', 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'DRB', 'TRB', 'AST', 'STL', 'TOV']
#
# Data types of columns:
# Player     object
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# 3P        float64
# 3PA       float64
# 2P        float64
# 2PA       float64
# FT        float64
# FTA       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# TOV       float64
# dtype: object
#
# Checking for NaN values in Test Case 1: ['LeBron James']
# Calculated averages for 1 players
# No NaN values found in the result.
#
# Checking for NaN values in Test Case 2: ['Chet Holmgren']
# Calculated averages for 1 players
# No NaN values found in the result.
#
# Checking for NaN values in Test Case 3: ['LeBron James', 'Chet Holmgren']
# Calculated averages for 2 players
# No NaN values found in the result.
#
# Checking for NaN values in Test Case 4: ['LeBron James', 'Chet Holmgren', 'NonexistentPlayer']
# No data found for players: {'NonexistentPlayer'}
# Calculated averages for 3 players
# Columns with NaN values: ['GS', 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'DRB', 'TRB', 'AST', 'STL', 'TOV']
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
# C:\Users\Kehinde Awomuti\AppData\Local\Temp\ipykernel_21900\527535220.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()

# %%
from mlflow.models import validate_serving_input
import mlflow

mlflow.set_tracking_uri("databricks")

model_uri = 'models:/NBA_XGB_Final/1'

# The model is logged with an input example. MLflow converts
# it into the serving payload format for the deployed model endpoint,
# and saves it to 'serving_input_payload.json'
serving_payload = """{
  "dataframe_split": {
    "columns": [
      "Player"
    ],
    "data": [
      [
        "Emoni Bates"
      ],
      [
        "Luke Hemmings"
      ]
    ]
  }
}"""
# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# No data found for players: {'Luke Hemmings'}
# Calculated averages for 2 players
# c:\hoops_ml\src\inference\inference copy.py:90: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   player_averages = player_data.groupby('Player').apply(calc_player_stats).reset_index()
#           Player              Predicted PPG
# 0    Emoni Bates                       2.73
# 1  Luke Hemmings  Player data not available

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 import os
# ----> 3 project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..', '..'))
#       4 sys.path.append(project_root)
#       5 from src.preprocessing.prep import merge_data, preprocess_data
#
# NameError: name '__file__' is not defined
